# %% [markdown]
# # Get MLB Player Stats
# This notebook fetches and preprocesses MLB player data.

# %%
# !pip install pybaseball pandas numpy matplotlib seaborn scikit-learn torch --quiet

# %%
from pybaseball import batting_stats
import pandas as pd

df = batting_stats(1900)
df.head()
# Out:
#       IDfg  Season           Name Team  Age    G   AB   PA    H   1B  ...  \
# 0  1013485    1900   Honus Wagner  PIT   26  135  527  580  201  130  ...
# 1  1004158    1900    Elmer Flick  PHI   24  138  545  623  200  141  ...
# 3  1001682    1900  Jesse Burkett  STL   31  141  559  643  203  170  ...
# 2  1008542    1900    John McGraw  STL   27   99  334  447  115   99  ...
# 4  1011731    1900    Kip Selbach  NYG   28  141  523  611  176  131  ...
#
#    maxEV  HardHit  HardHit%  Events  CStr%  CSW%  xBA  xSLG  xwOBA  L-WAR
# 0    NaN      NaN       NaN       0    NaN   NaN  NaN   NaN    NaN    6.9
# 1    NaN      NaN       NaN       0    NaN   NaN  NaN   NaN    NaN    6.3
# 3    NaN      NaN       NaN       0    NaN   NaN  NaN   NaN    NaN    5.6
# 2    NaN      NaN       NaN       0    NaN   NaN  NaN   NaN    NaN    5.4
# 4    NaN      NaN       NaN       0    NaN   NaN  NaN   NaN    NaN    5.3
#
# [5 rows x 320 columns]

# %%
df = df[df['PA'] >= 200].reset_index(drop=True)
df_2023 = batting_stats(2023)
df_2024 = batting_stats(2024)

merged = pd.merge(df_2023, df_2023[['Name', 'OPS']], on='Name', suffixes=('', '_target'))

# %%
features = [
    'G', 'AB', 'H', 'HR', 'BB', 'SO', 'SB', '2B', '3B', 'OPS', 'OBP', 'SLG', 'wOBA', 
    'AVG', 'OBP', 'SLG', 'OPS', 'ISO', 'BABIP', 'BB%', 'K%', 'BB/K', 'HR/FB', 'wOBA', 
    'wRC', 'wRC+', 'WAR', 'LD%', 'GB%', 'FB%', 'Pull%', 'Cent%', 'Oppo%', 'Soft%', 
    'Med%', 'Hard%', 'EV', 'LA', 'Barrel%', 'HardHit%', 'O-Swing%', 'Z-Swing%', 
    'Swing%', 'O-Contact%', 'Z-Contact%', 'Contact%', 'SwStr%', 'Zone%', 'F-Strike%'
    ]

merged_data = merged[features + ['OPS_target']].dropna()
merged_data.to_csv('../data/processed_player_data.csv', index=False)
